# %%
pc = 1 # probabilità del complementare
for k in range(1,151):
    pc = pc*(365-k+1)/365
    print("k = ", k, ": p = ", round((1 - pc)*100,2), "%", sep="")
# Out:
# k = 1: p = 0.0%
# k = 2: p = 0.27%
# k = 3: p = 0.82%
# k = 4: p = 1.64%
# k = 5: p = 2.71%
# k = 6: p = 4.05%
# k = 7: p = 5.62%
# k = 8: p = 7.43%
# k = 9: p = 9.46%
# k = 10: p = 11.69%
# k = 11: p = 14.11%
# k = 12: p = 16.7%
# k = 13: p = 19.44%
# k = 14: p = 22.31%
# k = 15: p = 25.29%
# k = 16: p = 28.36%
# k = 17: p = 31.5%
# k = 18: p = 34.69%
# k = 19: p = 37.91%
# k = 20: p = 41.14%
# k = 21: p = 44.37%
# k = 22: p = 47.57%
# k = 23: p = 50.73%
# k = 24: p = 53.83%
# k = 25: p = 56.87%
# k = 26: p = 59.82%
# k = 27: p = 62.69%
# k = 28: p = 65.45%
# k = 29: p = 68.1%
# k = 30: p = 70.63%
# k = 31: p = 73.05%
# k = 32: p = 75.33%
# k = 33: p = 77.5%
# k = 34: p = 79.53%
# k = 35: p = 81.44%
# k = 36: p = 83.22%
# k = 37: p = 84.87%
# k = 38: p = 86.41%
# k = 39: p = 87.82%
# k = 40: p = 89.12%
# k = 41: p = 90.32%
# k = 42: p = 91.4%
# k = 43: p = 92.39%
# k = 44: p = 93.29%
# k = 45: p = 94.1%
# k = 46: p = 94.83%
# k = 47: p = 95.48%
# k = 48: p = 96.06%
# ...
